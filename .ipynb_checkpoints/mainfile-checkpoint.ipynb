# %%
# first introduction commit

# %%
import tensorflow as tf

train_dir = r"C:\Users\DELL\OneDrive\Desktop\fruit-vege\fruit-vegitable-image-classification\data\train"
val_dir = r"C:\Users\DELL\OneDrive\Desktop\fruit-vege\fruit-vegitable-image-classification\data\validation"
test_dir = r"C:\Users\DELL\OneDrive\Desktop\fruit-vege\fruit-vegitable-image-classification\data\test"

# Load training data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Load validation data
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Load test data
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 test_dir = r"C:\Users\DELL\OneDrive\Desktop\fruit-vege\fruit-vegitable-image-classification\data\test"
#       7 # Load training data
# ----> 8 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#       9     train_dir,
#      10     labels="inferred",
#      11     label_mode="int",
#      12     class_names=None,
#      13     color_mode="rgb",
#      14     batch_size=32,
#      15     image_size=(256, 256),
#      16     shuffle=True,
#      17     seed=None,
#      18     validation_split=None,
#      19     subset=None,
#      20     interpolation="bilinear",
#      21     follow_links=False,
#      22     crop_to_aspect_ratio=False,
#      23     pad_to_aspect_ratio=False,
#      24     data_format=None,
#      25     verbose=True,
#      26 )
#      28 # Load validation data
#      29 val_ds = tf.keras.preprocessing.image_dataset_from_directory(
#      30     val_dir,
#      31     labels="inferred",
#    (...)     46     verbose=True,
#      47 )
#
# File C:\Python311\Lib\site-packages\keras\src\utils\image_dataset.py:168, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     166     crop_to_aspect_ratio = kwargs.pop("smart_resize")
#     167 if kwargs:
# --> 168     raise TypeError(f"Unknown keywords argument(s): {tuple(kwargs.keys())}")
#     169 if labels not in ("inferred", None):
#     170     if not isinstance(labels, (list, tuple)):
#
# TypeError: Unknown keywords argument(s): ('pad_to_aspect_ratio', 'data_format', 'verbose')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## Data preprocessing

# %%
## Training data preprocessing
