# %%
# first introduction commit

# %%
import tensorflow as tf

train_dir = r"C:\Users\DELL\OneDrive\Desktop\fruit-vege\fruit-vegitable-image-classification\data\train"
val_dir = r"C:\Users\DELL\OneDrive\Desktop\fruit-vege\fruit-vegitable-image-classification\data\validation"
test_dir = r"C:\Users\DELL\OneDrive\Desktop\fruit-vege\fruit-vegitable-image-classification\data\test"

# Load training data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(64,64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Load validation data
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    labels='inferred',
    label_mode='categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(64,64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 3115 files belonging to 36 classes.
# Found 351 files belonging to 36 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## Model Building

# %%
cnn = tf.keras.models.Sequential()
# Out:
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu', input_shape=(64, 64, 3)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# Out:
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.5))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=120, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=36, activation='softmax'))

# %%
cnn.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
training_history = cnn.fit(x=train_ds, validation_data=val_ds, epochs=30)
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 98/98 [==============================] - 90s 866ms/step - loss: 10.1739 - accuracy: 0.0421 - val_loss: 3.5375 - val_accuracy: 0.0598
# Epoch 2/30
# 98/98 [==============================] - 81s 764ms/step - loss: 3.8935 - accuracy: 0.0501 - val_loss: 3.4002 - val_accuracy: 0.1481
# Epoch 3/30
# 98/98 [==============================] - 76s 725ms/step - loss: 4.1099 - accuracy: 0.0780 - val_loss: 3.3792 - val_accuracy: 0.1709
# Epoch 4/30
# 98/98 [==============================] - 73s 709ms/step - loss: 4.3160 - accuracy: 0.1111 - val_loss: 3.0515 - val_accuracy: 0.2764
# Epoch 5/30
# 98/98 [==============================] - 80s 676ms/step - loss: 3.3693 - accuracy: 0.1528 - val_loss: 2.7244 - val_accuracy: 0.3333
# Epoch 6/30
# 98/98 [==============================] - 71s 670ms/step - loss: 3.7141 - accuracy: 0.2061 - val_loss: 2.5334 - val_accuracy: 0.4217
# Epoch 7/30
# 98/98 [==============================] - 76s 717ms/step - loss: 3.5194 - accuracy: 0.2465 - val_loss: 2.4386 - val_accuracy: 0.4530
# Epoch 8/30
# 98/98 [==============================] - 71s 669ms/step - loss: 2.8829 - accuracy: 0.3034 - val_loss: 2.6107 - val_accuracy: 0.3960
# Epoch 9/30
# 98/98 [==============================] - 68s 637ms/step - loss: 3.6136 - accuracy: 0.3499 - val_loss: 1.8389 - val_accuracy: 0.5670
# Epoch 10/30
# 98/98 [==============================] - 67s 636ms/step - loss: 2.7297 - accuracy: 0.4051 - val_loss: 1.7517 - val_accuracy: 0.6182
# Epoch 11/30
# 98/98 [==============================] - 70s 668ms/step - loss: 2.4275 - accuracy: 0.4501 - val_loss: 1.7192 - val_accuracy: 0.6524
# Epoch 12/30
# 98/98 [==============================] - 67s 642ms/step - loss: 2.6017 - accuracy: 0.4681 - val_loss: 1.7394 - val_accuracy: 0.6239
# Epoch 13/30
# 98/98 [==============================] - 67s 632ms/step - loss: 1.9524 - accuracy: 0.5403 - val_loss: 1.6266 - val_accuracy: 0.6781
# Epoch 14/30
# 98/98 [==============================] - 79s 752ms/step - loss: 2.0371 - accuracy: 0.5425 - val_loss: 1.3211 - val_accuracy: 0.7493
# Epoch 15/30
# 98/98 [==============================] - 86s 816ms/step - loss: 1.8163 - accuracy: 0.5929 - val_loss: 1.2418 - val_accuracy: 0.7749
# Epoch 16/30
# 98/98 [==============================] - 93s 862ms/step - loss: 2.3263 - accuracy: 0.6080 - val_loss: 1.2223 - val_accuracy: 0.7863
# Epoch 17/30
# 98/98 [==============================] - 98s 908ms/step - loss: 1.7538 - accuracy: 0.6424 - val_loss: 1.5180 - val_accuracy: 0.7778
# Epoch 18/30
# 98/98 [==============================] - 73s 690ms/step - loss: 1.7326 - accuracy: 0.6523 - val_loss: 1.4293 - val_accuracy: 0.8148
# Epoch 19/30
# 98/98 [==============================] - 82s 779ms/step - loss: 1.6399 - accuracy: 0.6806 - val_loss: 1.6217 - val_accuracy: 0.7664
# Epoch 20/30
# 98/98 [==============================] - 128s 1s/step - loss: 1.7040 - accuracy: 0.6918 - val_loss: 1.1963 - val_accuracy: 0.8205
# Epoch 21/30
# 98/98 [==============================] - 123s 1s/step - loss: 1.2687 - accuracy: 0.7072 - val_loss: 1.2463 - val_accuracy: 0.8376
# Epoch 22/30
# 98/98 [==============================] - 93s 880ms/step - loss: 1.2141 - accuracy: 0.7441 - val_loss: 1.1178 - val_accuracy: 0.8490
# Epoch 23/30
# 98/98 [==============================] - 93s 878ms/step - loss: 1.2277 - accuracy: 0.7483 - val_loss: 1.4516 - val_accuracy: 0.8433
# Epoch 24/30
# 98/98 [==============================] - 73s 692ms/step - loss: 1.1776 - accuracy: 0.7560 - val_loss: 1.0739 - val_accuracy: 0.8832
# Epoch 25/30
# 98/98 [==============================] - 80s 764ms/step - loss: 1.2954 - accuracy: 0.7605 - val_loss: 1.3989 - val_accuracy: 0.7806
# Epoch 26/30
# 98/98 [==============================] - 80s 759ms/step - loss: 1.0677 - accuracy: 0.7907 - val_loss: 1.1791 - val_accuracy: 0.8604
# Epoch 27/30
# 98/98 [==============================] - 87s 825ms/step - loss: 1.1453 - accuracy: 0.7862 - val_loss: 1.2039 - val_accuracy: 0.8661
# Epoch 28/30
# 98/98 [==============================] - 80s 752ms/step - loss: 1.0331 - accuracy: 0.7974 - val_loss: 1.7936 - val_accuracy: 0.8490
# Epoch 29/30
# 98/98 [==============================] - 85s 798ms/step - loss: 1.0645 - accuracy: 0.7987 - val_loss: 1.3125 - val_accuracy: 0.8604
# Epoch 30/30
# 98/98 [==============================] - 117s 1s/step - loss: 1.0848 - accuracy: 0.8064 - val_loss: 1.2881 - val_accuracy: 0.9259

# %%
cnn.save('trained-model.keras')

# %%
training_history.history
import json
with open('training_hist.json','w') as f:
    json.dump(training_history.history,f)

# %%
print(training_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
training_history.history['val_accuracy'][-1]
# Out:
# 0.9259259104728699

# %%
epochs = [i for i in range(1,31)]
plt.plot(epochs, training_history.history['accuracy'],color='red')
plt.xlabel('Epochs')
plt.ylabel('Training accuracy')
plt.title('Visualization of training accuracy result')
plt.show()

# %%
plt.plot(epochs, training_history.history['val_accuracy'],color='blue')
plt.xlabel('No of Epochs')
plt.ylabel('Validation accuracy')
plt.title('Visualization of Validation accuracy result')
plt.show()
